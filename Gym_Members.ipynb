# %% [markdown]
# <a href="https://colab.research.google.com/github/guadalupesbel-commits/EstadisticaVerano2026/blob/main/Gym_Members.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **GYM MEMBERS**

# %% [markdown]
# A continuación se presentará un ejemplo que la mayoría de los gimnasios o entrenadores tiene respecto a como ayudar a sus clientes respecto a su rendimiento y progreso en el gym.. Tomamos en cuenta varios datos como por ejemplo la edad, peso, estatura, frecuencia cardiaca, duración de la rutina, tipo de entrenamiento, frecuencia semanal y las calorías quemadas.
#
# Toda esta información nos proporcionara cuales variables es la que más aporta para quemar calorías y finalmente obtener un análisis y saber cuál es la variable que resulta ser más eficiente en este problema dado que es necesario saber cuántas calorías son quemadas.
#
# Basándonos en los datos de “Kaggle” de ‘Gym Members Exercise Dataset’ Pudimos tomar información necesaria para poder saber cuál es la variable independiente en este caso son las calorías quemadas, y nuestra variable dependiente que fue la duración de las rutinas
#
# Sin embargo, tenemos que tomar en cuenta que se aplicaron técnicas estadísticas descriptivas que ayudaron a tener nuestra base de datos, más aparte de usar variables categóricas que incluyeron el género o el tipo de entrenamiento, o las numéricas que se incluyeron la edad, peso, entre otras.
#
# Mas aparte se consideró la regresión lineal simple ya que con el conjunto de las variables numéricas como las calorías quemadas o las sesiones de entrenamiento calculada en horas se asumen que las calorías quemadas aumentas de manera proporcional con las sesiones de entrenamiento.
#
# Además, que con toda esta información es confiable por que se tomaron en cuenta diferentes pruebas, variables o diferentes graficas, como, por ejemplo, de las variables se tomaron en cuenta una dependiente y una independiente y esto nos ayudó a saber cuáles eran los resultados de los miembros que están en el gimnasio
#
# Tomando en cuenta la base de datos y nuestra grafica de dispersión, tenemos en cuenta que nuestra variable dependiente (duración de la rutina) $“X”$ Aumenta nuestra variable independiente (calorías quemadas) $“Y”$. Además de que obtuvimos el valor de coeficiente de correlación de $0.9081$ que esto se puede interpretar que existe una relación lineal muy fuerte y directa entre las variables.
#
# También que nuestro porcentaje de coeficiente de determinación es de $82.47%$, basándonos que también tenemos nuestra ecuación de regresión que fue $“R²=0.8247”$. Tomando en cuenta estos resultados nos percatamos que tuvimos un ajuste fuerte y positivo para los miembros del Gimnasio.
#
# Sobre nuestro modelo obtuvimos que por cada hora se queman $721.78$ calorías y por el otro lado sabemos que una persona sin hacer mucho esfuerzo no puede quemar calorías a diferencia de alguien que está activo.
#
#
#
# Conclusión
#
# Después de analizar nuestras graficas sabemos que tennos una relación directa y clara ya que a medida que aumenta el tiempo de las rutinas aumentaran las calorías quemadas, ya que sabemos identificar en nuestro definís calórico sería mejor si tenemos nuestras rutinas de mejor calidad y/o extensas.
#
# Gracias a este modelo tenemos un nivel de confianza del 95% confiando en este modelo sabemos que nuestro intervalo va de $-28.73 a 25.84$ y nuestra variable dependiente de la podemos definir que podemos quemar de 700 calorías hasta 743 calorías lo que nos indica que nuestra duración de la rutina tiene un efecto real y medible en el modelo
#
# Sin embargo, nuestros resultados tienen ciertas limitaciones como por ejemplo tenemos valores negativos, esto significa que podemos quemar de -300c a 300c por lo que nuestro Grafico muestre residuos o datos estandarizados ya que al parecer no cumplen con la homocedasticidad. Por lo que es necesario realizar más pruebas estadísticas.
#
# Añadiendo al análisis observamos que nuestro desgaste calórico va muy bien, pero una recomendación es darle un poco más de calidad a la rutina y un poco más de descanso, también para mejorar nuestro análisis seria considerar más variables.

# %% [markdown]
# ***INTRODUCCION***

# %% [markdown]
# **1.-¿Qué problema desea resolver el gimnasio?** Comprender mejor qué factores influyen en el gasto calórico durante una sesión de entrenamiento
#
# **2.-¿Qué variables se analizarán?** Las base de datos fueron la edad, peso, estatura, frecuencia cardiaca, duración de la sesión, tipo de entrenamiento, frecuencia semanal y calorías quemadas
#
# **3.-¿Por qué es útil estudiar la relación entre estas variables?**  Porque nos van a servir para ver cuales variables es la que mas aporta para quemar mas calorias
#
# **4.-¿Cuál es el objetivo general del análisis?** Analisar las variables y tener un analisis y saber cual es la variable y que resultado daciertas variables

# %% [markdown]
# ***METODOLOGIA***

# %% [markdown]
# **1.-¿Que base de datos se aplico?**

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/guadalupesbel-commits/EstadisticaVerano2026/refs/heads/main/Gym_Members/gym_members_exercise_tracking-selected-columns.csv")

df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type
# 0                        1.69           1313.0         Yoga
# 1                        1.30            883.0         HIIT
# 2                        1.11            677.0       Cardio
# 3                        0.59            532.0     Strength
# 4                        0.64            556.0     Strength
# ..                        ...              ...          ...
# 968                      1.57           1364.0     Strength
# 969                      1.38           1260.0     Strength
# 970                      1.72            929.0       Cardio
# 971                      1.10            883.0         HIIT
# 972                      0.75            542.0     Strength
#
# [973 rows x 10 columns]

# %% [markdown]
# **2.-¿Cuál fue la variable independiente y cuál fue la variable dependiente?**

# %% [markdown]
# Considerando que nuestra variable independiente son: Calories_Burned
# y nuestra variable dependiente son: Session_Duration (hours)

# %% [markdown]
# **3.-¿Qué técnica estadística se aplicó?**

# %% [markdown]
# En esta base de datos se aplico tecnicas de estadistica descriptiva que ayudaron a organizar la tabla y en la estructura de las variables que es la organizacion de las variables categoricas como el genero o el tipo de entrenamiento y las numericas que fue la edad, peso, etc
#
# y se utilizo regresión lineal multi-variada: Para predecir las Calorías Quemadas (Calories_Burned) basándose en variables independientes como la duración de la sesión, el peso y la frecuencia cardíaca promedio.

# %% [markdown]
# **4.-¿Por qué se eligió regresión lineal simple?**

# %% [markdown]
# Se consideraria la regresion lineal simple ya que el conjunto de datos contiene variables numéricas continuas (como Calories_Burned, Session_Duration, Max_BPM). Si se asume que, por ejemplo, las calorías quemadas aumentan de manera proporcional al tiempo de la sesión, una línea recta es la forma más sencilla de representar esa relación:

# %% [markdown]
# **5.-¿Qué estadísticos, gráficos o pruebas se utilizaron para sustentar el análisis?**

# %% [markdown]
# Se utilizaron pruebas, o diferentes variables, ademas de saber cuales eran nuestras variables dependientes e independientes, y se aplicaron graficas de dispersion, ya que teniamos que ver que tan fuerte era la recta de las graficas y saber como iban los resultados de los miembros del gym, ademas de ver los coeficientes de correlacion y de determinacion

# %%
Y = df["Calories_Burned"]      # Variable independiente
X = df["Session_Duration (hours)"]    # Variable dependiente

# %% [markdown]
# **RESULTADOS**

# %% [markdown]
# **1.-¿Qué muestran los gráficos de dispersión?**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Session_Duration (hours)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calories_Burned', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# El gráfico de dispersión muestra que las las sesiones con mas horas($X$) aumenta las calorias quemadas ($Y$)

# %% [markdown]
# **2.-¿Cuál fue el valor del coeficiente de correlación y cómo se interpreta?**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9081
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de $r=0.9081$ indica que existe una relación lineal muy fuerte y directa entre las variables $X$ e $Y$.

# %% [markdown]
# **3.-¿Cuál fue el coeficiente de determinación y qué porcentaje de la variabilidad explica el modelo?**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo = sm.OLS(Y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

# %%
# Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)

print(f"Coeficiente de determinación: {r2: 0.2%}")
# Out:
# Coeficiente de determinación:  82.47%

# %% [markdown]
# **4.-¿Cuál es la ecuación de regresión obtenida?**

# %% [markdown]
# **$R^2=0.8247$**

# %% [markdown]
# **5.-¿Qué significa la pendiente en el contexto del gimnasio?**

# %% [markdown]
# Una vez ajustado el modelo de regresión lienal, se obtiene un coeficiente calorico de $R^2=0.8247$. Entonces teniendo las horas de secion y el modelo ajustado, sólo podemos justificar la variabilidad en las calorias quemadas en un 82.47%, lo que es muy alto que fue considerado un ajuste fuertey positivo para los GYM RATS

# %% [markdown]
# **6.-¿Qué indican los residuales sobre la calidad del modelo?**

# %%
import pandas as pd
import statsmodels.api as sm

# Load the dataframe
df = pd.read_csv("https://raw.githubusercontent.com/guadalupesbel-commits/EstadisticaVerano2026/refs/heads/main/Gym_Members/gym_members_exercise_tracking-selected-columns.csv")

# Define X and Y variables
Y = df["Calories_Burned"]      # Variable dependiente (originally independent in comment, but dependent in code)
X = df["Session_Duration (hours)"]    # Variable independiente (originally dependent in comment, but independent in code)

# Add a constant to the independent variable
x_constante = sm.add_constant(X)

# Create and fit the OLS model
modelo = sm.OLS(Y, x_constante).fit()

# Print the model parameters
modelo.params
# Out:
# const                        -1.446459
# Session_Duration (hours)    721.786016
# dtype: float64

# %% [markdown]
# **7.-¿Qué estimación o predicción se obtuvo con el modelo?**

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=-1.446459+721.786016X
# $$
#
# Este modelo estima que la constancia que fue:-1.446459 por lo que el valor esperado de la duración de la sesión es 0 y que Session_Duration (hours) es 721.786016 lo que indica que por cada hora adicional de la duración de la sesión

# %% [markdown]
# **CONCLUSIONES**

# %% [markdown]
# **1.-¿Qué hallazgos principales se obtuvieron?**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.9,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Session_Duration (hours)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calories_Burned', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    loc='best',
    fontsize=10
)

# %% [markdown]
# Por lo que podemos ver en la grafica hay una relacion directa y clara, ya que a medida que aumenta el tiempo en la sesion, aumentaran las calorias quemadas.

# %% [markdown]
# **2.-¿La variable independiente permite explicar adecuadamente la variable dependiente?**

# %% [markdown]
# Si, ya que con el contexto gimnasio sabemos identificar que mientras mas calorias quememos, eso significa que hemos entrenado por mas horas o que nuestra sesion son mas extensas

# %% [markdown]
# **3.-¿Qué tan confiable es el modelo construido?**

# %%
modelo.conf_int(alpha=0.05)
# Out:
#                                    0           1
# const                     -28.738459   25.845542
# Session_Duration (hours)  700.830270  742.741762

# %% [markdown]
# Este modelo muestra un nivel de confianza del 95% de confianza. Ademas de que el intervalo va de $-28.73$ a $25.84$ y con una variable que va de $700.83$ a $742.74$
#
# Lo cual indica que la duracion de la sesion tiene un efecto real y medible en el modelo

# %% [markdown]
# **4.-¿Qué limitaciones tiene el análisis?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, residuales,      # <-----------------
    marker="o",       # forma: googlear "matplotlib.markers"
    color='#F527D3',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.1,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Gráfico de línea
plt.plot(
    X, y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Session_Duration (hours)', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Calories_Burned', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

plt.legend(
    fontsize=10,
    loc='best'
)

# %% [markdown]
# Como vemos el eje de calorias tiene valores negativos $(-300 a 300)$  .Por lo que sigiere que el grafico muestra residuos o los datos estandarizados, ya que no se pueden quemar calorias
#
# . Además, los datos parecen no cumplir cavalmente con la homoscedasticidad. Sin embargo, pese a lo que se observa, se realizarán las pruebas estadísticas.

# %% [markdown]
# **5.-¿Qué recomendación general se le daría al gimnasio?**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro-Wilk es el más confiable
# n >= 30, Histograma o Q-Q plot

# test de Shapiro-Wilk
1
# H0: Hay normalidad    0.4172971767713699
0.05
# H1: No hay normalidad
0

# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.003841645423152361

# %% [markdown]
# Como recomendación es que van muy bien con el desgaste calórico pero sería mejor darle un poco más de calidad, aunque sea por más tiempo pero con calidad en el ejercicio

# %% [markdown]
# **6.-¿Conviene usar sólo esta variable o sería mejor considerar otras variables adicionales?**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.0000

# %% [markdown]
# El hecho de que exista heterocedasticidad sugiere que la variable actual no esx suficiente para explicar y lo mejor sera incluir mas variables para capturar mejor varibilidad de los datos

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Y ~ X
modelo_lineal = ols('Calories_Burned ~ Q("Session_Duration (hours)")', data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                   df        sum_sq       mean_sq            F  \
# Q("Session_Duration (hours)")    1.0  5.958764e+07  5.958764e+07  4568.674447
# Residual                       971.0  1.266442e+07  1.304265e+04          NaN
#
#                                PR(>F)
# Q("Session_Duration (hours)")     0.0
# Residual                          NaN

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type
# 0                        1.69           1313.0         Yoga
# 1                        1.30            883.0         HIIT
# 2                        1.11            677.0       Cardio
# 3                        0.59            532.0     Strength
# 4                        0.64            556.0     Strength
# ..                        ...              ...          ...
# 968                      1.57           1364.0     Strength
# 969                      1.38           1260.0     Strength
# 970                      1.72            929.0       Cardio
# 971                      1.10            883.0         HIIT
# 972                      0.75            542.0     Strength
#
# [973 rows x 10 columns]

# %%
# Voy hacer anova para hacer regresion lineal
